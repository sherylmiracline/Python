# %% [markdown]
# Labsheet 13: Retriving Data from Web and Parsing
# Name: A.Sheryl Miracline
# Class: I-M.Sc.Data Science - 'A'
# Roll No.: 235229135

# %% [markdown]
# Question 1: Retrieve data from web page using urllib and print the frequency of words from that page.

# %%
import urllib.request
from bs4 import BeautifulSoup
from collections import Counter
import re

# Define the URL of the web page you want to scrape
url = "https://www.w3schools.com/"

# Function to fetch the web page content and parse it
def fetch_and_parse(url):
    try:
        # Fetch the web page content
        response = urllib.request.urlopen(url)
        html_content = response.read()

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, "html.parser")

        # Extract the text from the HTML content
        text = soup.get_text()

        return text
    except Exception as e:
        print("An error occurred:", str(e))
        return None

# Function to calculate word frequencies and print them
def calculate_word_frequencies(text):
    if text is None:
        return

    # Tokenize the text into words using regular expressions
    words = re.findall(r'\w+', text.lower())

    # Calculate word frequencies using Counter
    word_freq = Counter(words)

    # Print the word frequencies
    for word, freq in word_freq.most_common():
        print(f"{word}: {freq}")

if __name__ == "__main__":
    # Fetch and parse the web page content
    web_page_text = fetch_and_parse(url)

    # Calculate and print word frequencies
    calculate_word_frequencies(web_page_text)
# Out:
# learn: 91
# tutorial: 85
# certificate: 47
# reference: 41
# course: 39
# web: 36
# a: 36
# exercise: 34
# css: 30
# to: 30
# quiz: 30
# and: 28
# html: 26
# c: 20
# w3schools: 18
# code: 18
# your: 18
# our: 17
# javascript: 17
# python: 15
# for: 15
# examples: 15
# get: 14
# is: 14
# certified: 13
# data: 13
# create: 13
# sql: 12
# php: 12
# java: 12
# of: 12
# free: 11
# bootcamp: 10
# website: 10
# w3: 10
# learning: 10
# jquery: 10
# the: 10
# tutorials: 9
# spaces: 9
# bootstrap: 9
# editor: 9
# how: 8
# analytics: 8
# excel: 8
# templates: 8
# game: 8
# what: 8
# with: 8
# you: 8
# try: 8
# it: 8
# language: 8
# exercises: 7
# in: 7
# numpy: 7
# pandas: 7
# statistics: 7
# where: 7
# test: 7
# js: 7
# color: 7
# by: 6
# popularity: 6
# ai: 6
# server: 6
# start: 6
# typing: 6
# speed: 6
# newsletter: 6
# react: 6
# aws: 6
# xml: 6
# yourself: 6
# pages: 6
# example: 6
# services: 5
# my: 5
# google: 5
# scipy: 5
# cyber: 5
# security: 5
# join: 5
# vue: 5
# backend: 5
# ...

# %% [markdown]
# Question 2: Retrieve and display all hyperlinks from a webpage using BeautifulSoup.

# %%
import urllib.request
from bs4 import BeautifulSoup

# Define the URL of the web page you want to scrape
url = "https://www.w3schools.com/"

# Function to fetch the web page content and parse it
def fetch_and_parse(url):
    try:
        # Fetch the web page content
        response = urllib.request.urlopen(url)
        html_content = response.read()

        # Parse the HTML content using BeautifulSoup
        soup = BeautifulSoup(html_content, "html.parser")

        return soup
    except Exception as e:
        print("An error occurred:", str(e))
        return None

# Function to find and display all hyperlinks (HREF attributes)
def display_hyperlinks(soup):
    if soup is None:
        return

    # Find all anchor (a) tags in the HTML
    anchor_tags = soup.find_all("a")

    # Loop through the anchor tags and display the HREF attributes
    for tag in anchor_tags:
        href = tag.get("href")
        if href:
            print(href)

if __name__ == "__main__":
    # Fetch and parse the web page content
    parsed_html = fetch_and_parse(url)

    # Display all hyperlinks
    display_hyperlinks(parsed_html)
# Out:
# https://www.w3schools.com
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0)
# javascript:void(0);
# https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
# /signup/index.php
# https://profile.w3schools.com/log-in?redirect_url=https%3A%2F%2Fmy-learning.w3schools.com
# https://my-learning.w3schools.com
# https://campus.w3schools.com/collections/certifications
# /spaces/index.php
# https://billing.w3schools.com/products/spaces?frequency=monthly&changePlan=true
# https://spaces.w3schools.com/space/
# https://my-learning.w3schools.com
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# /bootcamp/index.php
# https://billing.w3schools.com/products/spaces?frequency=monthly&changePlan=true
# https://profile.w3schools.com/logout
# /bootcamp/index.php
# /spaces/index.php
# /signup/index.php
# ...

# %% [markdown]
# Question 3: Create a HTML file for the following Student Marks and print the number of students and their names and marks.

# %%
# Define the student data
students_data = [
    {"ID": "DS01", "Name": "Rex", "Mark1": 87, "Mark2": 57, "Mark3": 74},
    {"ID": "DS02", "Name": "Peter", "Mark1": 68, "Mark2": 98, "Mark3": 55},
]

# Create an HTML table
html_table = """
<!DOCTYPE html>
<html>
<head>
    <title>Student Marks</title>
</head>
<body>
    <h1>Student Marks</h1>
    <table border="1">
        <tr>
            <th>ID</th>
            <th>Name</th>
            <th>Mark1</th>
            <th>Mark2</th>
            <th>Mark3</th>
        </tr>
"""

# Loop through the student data and add rows to the table
for student in students_data:
    html_table += f"""
        <tr>
            <td>{student["ID"]}</td>
            <td>{student["Name"]}</td>
            <td>{student["Mark1"]}</td>
            <td>{student["Mark2"]}</td>
            <td>{student["Mark3"]}</td>
        </tr>
"""

# Close the HTML table
html_table += """
    </table>
</body>
</html>
"""

# Print the number of students and the HTML table
num_students = len(students_data)
print(f"Number of students: {num_students}")
print(html_table)
# Out:
# Number of students: 2
#
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Student Marks</title>
# </head>
# <body>
#     <h1>Student Marks</h1>
#     <table border="1">
#         <tr>
#             <th>ID</th>
#             <th>Name</th>
#             <th>Mark1</th>
#             <th>Mark2</th>
#             <th>Mark3</th>
#         </tr>
#
#         <tr>
#             <td>DS01</td>
#             <td>Rex</td>
#             <td>87</td>
#             <td>57</td>
#             <td>74</td>
#         </tr>
#
#         <tr>
#             <td>DS02</td>
#             <td>Peter</td>
#             <td>68</td>
#             <td>98</td>
#             <td>55</td>
#         </tr>
#
#     </table>
# </body>
# </html>

# %% [markdown]
# Question 4: Create a JSON file for the following students marks and print the number of students and their names and marks.

# %%
import json

# Define a dictionary with student names and marks
student_marks = {
    "Alice": 92,
    "Bob": 78,
    "Charlie": 85,
    "David": 95,
    "Eve": 88
}

# Calculate the number of students
num_students = len(student_marks)

# Create a JSON file with the student data
with open("student_marks.json", "w") as json_file:
    json.dump(student_marks, json_file)

# Read the JSON file and print the information
with open("student_marks.json", "r") as json_file:
    data = json.load(json_file)
    print(f"Number of students: {num_students}")
    for student, marks in data.items():
        print(f"Student: {student}, Marks: {marks}")
# Out:
# Number of students: 5
# Student: Alice, Marks: 92
# Student: Bob, Marks: 78
# Student: Charlie, Marks: 85
# Student: David, Marks: 95
# Student: Eve, Marks: 88

# %% [markdown]
# Question 5: Crawl Weather of a city and display 7 day forecast.

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL of the weather page for Tiruchirappalli
url = "https://weather.com/weather/7day/l/Tiruchirapalli+TN+INXX0292:1:IN"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Locate the element containing the 7-day weather forecast data
    forecast_container = soup.find("div", class_="DailyForecast--DisclosureList--u0yMq")
    
    # Extract and display the weather forecast for each day
    for day in forecast_container.find_all("div", class_="Disclosure--Disclosure--Cwa2d"):
        date = day.find("span", class_="DetailsSummary--daypartDate--1Mebr").get_text(strip=True)
        description = day.find("div", class_="DetailsSummary--dayDescription--1sxN1").get_text(strip=True)
        high_temp = day.find("span", class_="DetailsSummary--highTempValue--3x6cL").get_text(strip=True)
        low_temp = day.find("span", class_="DetailsSummary--lowTempValue--1DlJK").get_text(strip=True)
        
        print(f"Date: {date}")
        print(f"Description: {description}")
        print(f"High Temperature: {high_temp}")
        print(f"Low Temperature: {low_temp}")
        print()
else:
    print("Failed to retrieve the weather data.")
# Out:
# Failed to retrieve the weather data.

# %% [markdown]
# Question 6: Real Time Stock Prices Crawling and Display of a Specified Company.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Define the stock symbols
stock_symbols = ["INFY", "CTS"]

# Fetch historical stock data for the past year
start_date = "2022-09-19"  # Specify the start date
end_date = "2023-09-19"    # Specify the end date

# Create an empty DataFrame to store the stock data
stock_data = {}

# Fetch stock data for each symbol
for symbol in stock_symbols:
    stock_data[symbol] = yf.download(symbol, start=start_date, end=end_date)

# Plot the stock prices
plt.figure(figsize=(12, 6))

for symbol, data in stock_data.items():
    plt.plot(data.index, data["Adj Close"], label=symbol)

# Customize the plot
plt.title("Stock Price Movements")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import yfinance as yf
#       2 import matplotlib.pyplot as plt
#       4 # Define the stock symbols
#
# ModuleNotFoundError: No module named 'yfinance'
